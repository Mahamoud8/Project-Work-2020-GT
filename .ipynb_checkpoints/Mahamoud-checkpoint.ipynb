# %%
#Which areas received the most money?
#Which areas had the most applications?


# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
PPP_data = pd.read_csv('PPP Data/PPP Data 150k GA.csv')
PPP_data.head()
# Out:
#    Loan Amount         City State    Zip  NAICSCode  \
# 0  $149,998.30      DECATUR    GA  30033   621210.0
# 1  $149,981.92   BLACKSHEAR    GA  31516   713910.0
# 2  $149,952.00    ELLENWOOD    GA  30294   812199.0
# 3  $149,952.00      DECATUR    GA  30034   484121.0
# 4  $149,924.00      ATLANTA    GA  30338   339116.0
#
#                       BusinessType RaceEthnicity      Gender     Veteran  \
# 0  Limited  Liability Company(LLC)    Unanswered  Male Owned  Unanswered
# 1          Non-Profit Organization         White  Male Owned  Unanswered
# 2  Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# 3  Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# 4                      Corporation    Unanswered  Unanswered  Unanswered
#
#   NonProfit  JobsRetained DateApproved  \
# 0       NaN          14.0    4/14/2020
# 1         Y          32.0    4/28/2020
# 2       NaN          14.0    6/18/2020
# 3       NaN          11.0    6/20/2020
# 4       NaN           0.0    4/29/2020
#
#                                    Lender       CD
# 0                     Newton Federal Bank  GA - 04
# 1                         Primesouth Bank  GA - 01
# 2                                 WebBank  GA - 04
# 3                                 WebBank  GA - 04
# 4  Wells Fargo Bank, National Association  GA - 06

# %%
total_city = str(PPP_data["City"].nunique())
total_city
# Out:
# '1257'

# %%
PPP_data.rename(columns = {" Loan Amount ":"Loan Amount"}, inplace=True)

# %%
def elises_func(stringy):
        our_float = stringy.replace("   ","").replace("  ","").replace(" ","").replace(",","").replace("$","").replace("-","")
        if not our_float:
            our_float = 0
        else:
            our_float = float(our_float)
        
        return our_float

# %%
PPP_data["Loan Amount"] = PPP_data["Loan Amount"].apply(elises_func)
PPP_data.head()
# Out:
#    Loan Amount        City State    Zip  NAICSCode  \
# 0    149998.30     DECATUR    GA  30033   621210.0
# 1    149981.92  BLACKSHEAR    GA  31516   713910.0
# 2    149952.00   ELLENWOOD    GA  30294   812199.0
# 3    149952.00     DECATUR    GA  30034   484121.0
# 4    149924.00     ATLANTA    GA  30338   339116.0
#
#                       BusinessType RaceEthnicity      Gender     Veteran  \
# 0  Limited  Liability Company(LLC)    Unanswered  Male Owned  Unanswered
# 1          Non-Profit Organization         White  Male Owned  Unanswered
# 2  Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# 3  Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# 4                      Corporation    Unanswered  Unanswered  Unanswered
#
#   NonProfit  JobsRetained DateApproved  \
# 0       NaN          14.0    4/14/2020
# 1         Y          32.0    4/28/2020
# 2       NaN          14.0    6/18/2020
# 3       NaN          11.0    6/20/2020
# 4       NaN           0.0    4/29/2020
#
#                                    Lender       CD
# 0                     Newton Federal Bank  GA - 04
# 1                         Primesouth Bank  GA - 01
# 2                                 WebBank  GA - 04
# 3                                 WebBank  GA - 04
# 4  Wells Fargo Bank, National Association  GA - 06

# %%
PPP_data["City"].value_counts()

#Metro Atlanta has the largest applications for PPP loans (20218).
# Out:
# ATLANTA            20218
# MARIETTA            5604
# ALPHARETTA          3823
# SAVANNAH            3413
# LAWRENCEVILLE       3034
#                    ...
# CARTERSVILLE,          1
# IRWINVILLE             1
# PEACHSTREE CITY        1
# ST. SIMONS ISL.        1
# PEACTREE CORNER        1
# Name: City, Length: 1257, dtype: int64

# %%
city_most_app = PPP_data["City"].value_counts()
number_of_applications = PPP_data.groupby("City").nunique()
averageLoanAmount = PPP_data.groupby('City').mean()["Loan Amount"]
averageJobsRetained = PPP_data.groupby('City').mean()['JobsRetained']

bins = [0, 25000, 50000, 75000, 100000, 125000, 150000]
# Create labels for these bins
labels = ["<$25K", "<$50K","<$75K", "<$100K","<$125K", "<$150K"]
top_ten_cities = city_most_app.head(10)

top_ten_cities_df=pd.DataFrame(top_ten_cities )
top_ten_cities_df
x=top_ten_cities_df.index
y=top_ten_cities_df["City"]
plt.title("Top Ten Cities Application")
plt.xlabel("Cities")
plt.ylabel("Number of Applications")
plt.bar(x,y)
plt.xticks(x, rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x1c19f2e6d08>,
#   <matplotlib.axis.XTick at 0x1c19f2e62c8>,
#   <matplotlib.axis.XTick at 0x1c19f30ff08>,
#   <matplotlib.axis.XTick at 0x1c19f34bdc8>,
#   <matplotlib.axis.XTick at 0x1c19f3545c8>,
#   <matplotlib.axis.XTick at 0x1c19f354e08>,
#   <matplotlib.axis.XTick at 0x1c19f358748>,
#   <matplotlib.axis.XTick at 0x1c19f354f08>,
#   <matplotlib.axis.XTick at 0x1c19f35d1c8>,
#   <matplotlib.axis.XTick at 0x1c19f35d908>],
#  <a list of 10 Text xticklabel objects>)

# %%
def city_func(citystringy):
        our1_str = citystringy.replace("{","").replace(" ","").replace(",","").replace("1","").replace("2","").replace("3","").replace("4","").replace("5","").replace("6","").replace("7","").replace("8","")
        if not our1_str:
            our1_str != 1
        else:
            our1_str = str(our1_str)
        
        return our1_str

# %%
PPP_data["City"] = PPP_data["City"].apply(city_func)
PPP_data.head(10)
# Out:
#    Loan Amount        City State    Zip  NAICSCode  \
# 0    149998.30     DECATUR    GA  30033   621210.0
# 1    149981.92  BLACKSHEAR    GA  31516   713910.0
# 2    149952.00   ELLENWOOD    GA  30294   812199.0
# 3    149952.00     DECATUR    GA  30034   484121.0
# 4    149924.00     ATLANTA    GA  30338   339116.0
# 5    149920.00   SUGARHILL    GA  30518   236220.0
# 6    149910.00     ROSWELL    GA  30075   722513.0
# 7    149900.00      MORROW    GA  30260   562119.0
# 8    149900.00     ATLANTA    GA  30305   522310.0
# 9    149900.00       COMER    GA  30629   238220.0
#
#                       BusinessType RaceEthnicity      Gender      Veteran  \
# 0  Limited  Liability Company(LLC)    Unanswered  Male Owned   Unanswered
# 1          Non-Profit Organization         White  Male Owned   Unanswered
# 2  Limited  Liability Company(LLC)    Unanswered  Unanswered   Unanswered
# 3  Limited  Liability Company(LLC)    Unanswered  Unanswered   Unanswered
# 4                      Corporation    Unanswered  Unanswered   Unanswered
# 5                      Corporation    Unanswered  Unanswered   Unanswered
# 6  Limited  Liability Company(LLC)    Unanswered  Male Owned   Unanswered
# 7         Subchapter S Corporation         White  Male Owned  Non-Veteran
# 8  Limited  Liability Company(LLC)    Unanswered  Unanswered   Unanswered
# 9                      Corporation    Unanswered  Unanswered   Unanswered
#
#   NonProfit  JobsRetained DateApproved  \
# 0      None          14.0    4/14/2020
# 1         Y          32.0    4/28/2020
# 2      None          14.0    6/18/2020
# 3      None          11.0    6/20/2020
# 4      None           0.0    4/29/2020
# 5      None           9.0    4/27/2020
# 6      None          17.0    4/29/2020
# 7      None           0.0    4/16/2020
# 8      None           9.0     4/4/2020
# 9      None          18.0    4/14/2020
#
#                                    Lender       CD
# 0                     Newton Federal Bank  GA - 04
# 1                         Primesouth Bank  GA - 01
# 2                                 WebBank  GA - 04
# 3                                 WebBank  GA - 04
# 4  Wells Fargo Bank, National Association  GA - 06
# 5                    Peoples Bank & Trust  GA - 07
# 6                           Pinnacle Bank  GA - 06
# 7                         CornerstoneBank  GA - 05
# 8                             Ameris Bank  GA - 05
# 9                   United Community Bank  GA - 09

# %%
clean_cities = PPP_data[PPP_data["Loan Amount"] >= 0]
clean_cities["City"].value_counts()
sorted_clean_cities = clean_cities.sort_values(by="Loan Amount",ascending=False)
sorted_clean_cities
# Out:
#         Loan Amount         City State    Zip  NAICSCode  \
# 0         149998.30      DECATUR    GA  30033   621210.0
# 1         149981.92   BLACKSHEAR    GA  31516   713910.0
# 2         149952.00    ELLENWOOD    GA  30294   812199.0
# 3         149952.00      DECATUR    GA  30034   484121.0
# 4         149924.00      ATLANTA    GA  30338   339116.0
# ...             ...          ...   ...    ...        ...
# 138514         2.00     MARIETTA    GA  30067   445110.0
# 138515         1.00      ATLANTA    GA  30339   236115.0
# 138516         1.00     SAVANNAH    GA  31415   485119.0
# 138517         0.00  GAINESVILLE    GA  30504   561990.0
# 138518         0.00     MARIETTA    GA  30062   561990.0
#
#                            BusinessType RaceEthnicity      Gender  \
# 0       Limited  Liability Company(LLC)    Unanswered  Male Owned
# 1               Non-Profit Organization         White  Male Owned
# 2       Limited  Liability Company(LLC)    Unanswered  Unanswered
# 3       Limited  Liability Company(LLC)    Unanswered  Unanswered
# 4                           Corporation    Unanswered  Unanswered
# ...                                 ...           ...         ...
# 138514  Limited  Liability Company(LLC)    Unanswered  Unanswered
# 138515  Limited  Liability Company(LLC)    Unanswered  Unanswered
# 138516              Sole Proprietorship    Unanswered  Unanswered
# 138517                      Corporation    Unanswered  Unanswered
# 138518                      Corporation    Unanswered  Male Owned
#
#             Veteran NonProfit  JobsRetained DateApproved  \
# 0        Unanswered      None          14.0    4/14/2020
# 1        Unanswered         Y          32.0    4/28/2020
# 2        Unanswered      None          14.0    6/18/2020
# 3        Unanswered      None          11.0    6/20/2020
# 4        Unanswered      None           0.0    4/29/2020
# ...             ...       ...           ...          ...
# 138514   Unanswered      None           5.0    4/30/2020
# 138515   Unanswered      None           1.0    5/29/2020
# 138516   Unanswered      None           0.0    5/15/2020
# 138517   Unanswered      None           2.0     5/3/2020
# 138518  Non-Veteran      None          22.0     5/3/2020
#
#                                         Lender       CD
# 0                          Newton Federal Bank  GA - 04
# 1                              Primesouth Bank  GA - 01
# 2                                      WebBank  GA - 04
# 3                                      WebBank  GA - 04
# 4       Wells Fargo Bank, National Association  GA - 06
# ...                                        ...      ...
# 138514   Bank of America, National Association  GA - 06
# 138515   Bank of America, National Association  GA - 06
# 138516  Wells Fargo Bank, National Association  GA - 01
# 138517   Bank of America, National Association  GA - 09
# 138518     Newtek Small Business Finance, Inc.  GA - 06
#
# [138519 rows x 14 columns]

# %%
cities_max = clean_cities.groupby("City").sum().sort_values("Loan Amount",ascending=False) 
cities_max["Loan amounts in Millions"] = round(cities_max["Loan Amount"] / 1000000, 2)
cities_max.head(10)
# Out:
#                 Loan Amount        Zip     NAICSCode  JobsRetained  \
# City
# ATLANTA        6.764249e+08  613314438 -3.634009e+21 -1.556905e+22
# MARIETTA       1.806385e+08  168499452 -1.199038e+21 -4.021390e+21
# ALPHARETTA     1.344604e+08  114731677 -8.024334e+20 -2.370407e+21
# SAVANNAH       1.206367e+08  107194013 -5.718491e+20 -1.835451e+21
# CUMMING        8.207912e+07   79275211 -4.796153e+20 -1.577197e+21
# LAWRENCEVILLE  8.196713e+07   91184863 -4.611686e+20 -2.278173e+21
# DULUTH         7.927629e+07   78552184 -4.334985e+20 -1.743217e+21
# MACON          7.378171e+07   62912141 -2.121376e+20 -1.411176e+21
# AUGUSTA        7.290969e+07   61996619 -1.660207e+20 -9.500073e+20
# ROSWELL        7.257880e+07   66918479 -5.257322e+20 -1.577197e+21
#
#                Loan amounts in Millions
# City
# ATLANTA                          676.42
# MARIETTA                         180.64
# ALPHARETTA                       134.46
# SAVANNAH                         120.64
# CUMMING                           82.08
# LAWRENCEVILLE                     81.97
# DULUTH                            79.28
# MACON                             73.78
# AUGUSTA                           72.91
# ROSWELL                           72.58

# %%
cities_max.count
# Out:
# <bound method DataFrame.count of                      Loan Amount        Zip     NAICSCode  JobsRetained  \
# City
# ATLANTA             6.764249e+08  613314438 -3.634009e+21 -1.556905e+22
# MARIETTA            1.806385e+08  168499452 -1.199038e+21 -4.021390e+21
# ALPHARETTA          1.344604e+08  114731677 -8.024334e+20 -2.370407e+21
# SAVANNAH            1.206367e+08  107194013 -5.718491e+20 -1.835451e+21
# CUMMING             8.207912e+07   79275211 -4.796153e+20 -1.577197e+21
# ...                          ...        ...           ...           ...
# RINGGOLDQ           1.002500e+03      30736  4.533100e+05  1.000000e+00
# SAINTSIMMONSISLAND  1.000000e+03      31522  8.121120e+05  1.000000e+00
# BOULDERCRESTROAD    1.000000e+03      30294  4.853200e+05  0.000000e+00
# PORTWENWORTH        1.000000e+03      31407  4.853100e+05  5.000000e+02
# LAWRENCILLE         5.350000e+02      30045  4.841210e+05  1.000000e+00
#
#                     Loan amounts in Millions
# City
# ATLANTA                               676.42
# MARIETTA                              180.64
# ALPHARETTA                            134.46
# SAVANNAH                              120.64
# CUMMING                                82.08
# ...                                      ...
# RINGGOLDQ                               0.00
# SAINTSIMMONSISLAND                      0.00
# BOULDERCRESTROAD                        0.00
# PORTWENWORTH                            0.00
# LAWRENCILLE                             0.00
#
# [1197 rows x 5 columns]>

# %%
#Which areas received the most money?

top_ten_cities1 = cities_max.head(10)


x=top_ten_cities1.index
y=top_ten_cities1["Loan amounts in Millions"]
plt.bar(x,y)
plt.xticks(x, rotation="vertical")

plt.title("Top Ten Cities Money received")
plt.xlabel("Cities")
plt.ylabel("Money received (Millions)")
plt.bar(x,y)
plt.xticks(x, rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x1c1a6dc41c8>,
#   <matplotlib.axis.XTick at 0x1c19fc9c188>,
#   <matplotlib.axis.XTick at 0x1c1a5d1e0c8>,
#   <matplotlib.axis.XTick at 0x1c1a6dcbac8>,
#   <matplotlib.axis.XTick at 0x1c1a6dc4d48>,
#   <matplotlib.axis.XTick at 0x1c1a5d82ac8>,
#   <matplotlib.axis.XTick at 0x1c1a5d8b708>,
#   <matplotlib.axis.XTick at 0x1c1a5d9b7c8>,
#   <matplotlib.axis.XTick at 0x1c1a5da9388>,
#   <matplotlib.axis.XTick at 0x1c1a5db8788>],
#  <a list of 10 Text xticklabel objects>)
